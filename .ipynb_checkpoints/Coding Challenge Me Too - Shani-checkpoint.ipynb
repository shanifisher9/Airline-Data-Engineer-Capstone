# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

# %%
survey= pd.read_excel('Survey on Sexual Assault.xlsx')

# %%
survey.sample(5)
# Out:
#      Respondent ID  Collector ID          Start Date            End Date  \
# 370   1.107578e+10   247838599.0 2019-10-18 10:11:42 2019-10-18 10:17:46
# 576   1.107189e+10   247838599.0 2019-10-16 23:38:21 2019-10-16 23:40:26
# 140   1.107996e+10   247838599.0 2019-10-21 01:06:31 2019-10-21 01:09:46
# 41    1.108570e+10   247838599.0 2019-10-22 20:17:57 2019-10-22 20:19:21
# 506   1.107289e+10   247838599.0 2019-10-17 09:52:49 2019-10-17 09:55:38
#
#         IP Address  Email Address  First Name  Last Name  Custom Data 1  \
# 370  24.253.232.22            NaN         NaN        NaN            NaN
# 576   75.80.185.22            NaN         NaN        NaN            NaN
# 140  108.245.81.86            NaN         NaN        NaN            NaN
# 41   74.93.163.221            NaN         NaN        NaN            NaN
# 506  141.238.27.77            NaN         NaN        NaN            NaN
#
#     How old are you?  ... Was the perpetrator arrested?.1  \
# ...

# %%
survey.dtypes
# Out:
# Respondent ID                                                                                             float64
# Collector ID                                                                                              float64
# Start Date                                                                                         datetime64[ns]
# End Date                                                                                           datetime64[ns]
# IP Address                                                                                                 object
# Email Address                                                                                             float64
# First Name                                                                                                float64
# Last Name                                                                                                 float64
# ...

# %%
survey['How old were you when you were assaulted?'].unique()
# Out:
# array(['Response', 'Under 18', '18-24', '25-34', '35-44', '45-54', '65+',
#        '55-64'], dtype=object)

# %%
survey['How old are you?'].unique()
# Out:
# array(['Open-Ended Response', 26, 32, 34, 27, 31, 22, 57, 39, 30, 21, 25,
#        33, 19, 56, 24, 29, 28, 66, 36, 46, 48, 45, 40, 23, 18, 51, 70, 35,
#        38, 42, 44, 49, 20, 37, 43, 50, 59, 67, 55, 62, 54, 63, 47, 65, 52,
#        41, 61, 58, 53, 60, 80, 68, 72, 64, 75], dtype=object)

# %%
def clean_age_assaulted(x):
    """
    Author: Aungshuman
    Use like df['bun'] = df['bun'].apply(clean_labs)
    """
    if x == 'Under 18':
        print('Child')
    if x == '18-24':
        print('Teen')
    if x == '25-34':
        print('Adult')
    else:
        print('Older')

# %%
survey['when_assaulted'] = survey['How old were you when you were assaulted?'].apply(clean_age_assaulted)
# Out:
# Older
# Child
# Older
# Teen
# Older
# Adult
# Teen
# Older
# Teen
# Older
# Teen
# Older
# Child
# Older
# Child
# Older
# Teen
# Older
# Teen
# Older
# Child
# Older
# Adult
# Child
# Older
# Child
# Older
# Teen
# Older
# Child
# Older
# Child
# Older
# Child
# Older
# Child
# Older
# Child
# Older
# Child
# Older
# Child
# Older
# Child
# Older
# Child
# Older
# Teen
# Older
# Child
# Older
# Teen
# Older
# Child
# Older
# Older
# Older
# Adult
# Child
# Older
# Child
# Older
# Child
# Older
# Child
# Older
# Teen
# Older
# Child
# Older
# Teen
# Older
# Teen
# Older
# Child
# Older
# Adult
# Child
# Older
# Teen
# Older
# Teen
# Older
# Child
# Older
# Child
# Older
# Child
# Older
# Teen
# Older
# Child
# Older
# Adult
# Child
# Older
# Child
# Older
# Child
# Older
# Teen
# Older
# Child
# Older
# Child
# Older
# Teen
# Older
# Teen
# Older
# Child
# Older
# Adult
# Child
# Older
# Teen
# Older
# Older
# Adult
# Teen
# Older
# Adult
# Teen
# Older
# Older
# Child
# Older
# ...

# %%
def clean_age(x):
    """
    Author: Aungshuman
    Use like df['bun'] = df['bun'].apply(clean_labs)
    """
    if x <= 12:
        return Child
    if x > 12 and x <= 20:
        return Teen
    if x > 20 and x<=40:
        return Adult
    else:
        return Older

# %%
survey['age'] = int(survey['How old are you?']).apply(clean_age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-a3226dd54b88> in <module>
# ----> 1 survey['age'] = int(survey['How old are you?']).apply(clean_age)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#      91             return converter(self.iloc[0])
#      92         raise TypeError("cannot convert the series to "
# ---> 93                         "{0}".format(str(converter)))
#      94
#      95     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'int'>

# %%
survey['stage']=np.where(survey['How old are you?']<= 20, )

x = int(input(survey['How old are you?']))
if x <= 20:
        return Teen
if x > 20 and x <= 40:
        return Adult
else:
        return old
# Out:
# 0      Open-Ended Response
# 1                       26
# 2                       32
# 3                       34
# 4                       27
# 5                       31
# 6                       22
# 7                       57
# 8                       39
# 9                       30
# 10                      21
# 11                      25
# 12                      33
# 13                      19
# 14                      56
# 15                      24
# 16                      25
# 17                      29
# 18                      28
# 19                      66
# 20                      32
# 21                      36
# 22                      31
# 23                      46
# 24                      26
# 25                      29
# 26                      48
# 27                      36
# 28                      29
# 29                      45
#               ...
# 734                     54
# 735                     25
# 736                     31
# ...

# %%
survey['How old are you?'].astype(str).astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-47e0eba60bc4> in <module>
# ----> 1 survey['How old are you?'].astype(str).astype(float)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ...

# %%
int_age = int(survey['How old are you?'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-eff5938dd223> in <module>
# ----> 1 int_age = int(survey['How old are you?'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#      91             return converter(self.iloc[0])
#      92         raise TypeError("cannot convert the series to "
# ---> 93                         "{0}".format(str(converter)))
#      94
#      95     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'int'>

# %%
new_time = survey['How old are you?'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-9588532bc003> in <module>
# ----> 1 new_time = survey['How old are you?'].astype(float)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ...

# %%
#matplotlib.pyplot.bar('How old were you when you were assaulted?', data=survey)
#sns.boxplot(x=survey["when_assaulted"])
sns.barplot(x="when_assaulted", y="Did you report your assault?", data=survey)

# %%
ax = sns.barplot(x="when_assaulted", y="Did you report your assault?", data=survey, order=["Child", "Older", 'Adult'])
